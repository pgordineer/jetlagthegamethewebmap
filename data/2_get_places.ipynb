# %%
import pandas as pd

# %%
df = pd.read_csv("./data.csv")
df
# Out:
#     Unnamed: 0           publishedAt  \
# 0            0  2024-01-01T16:00:06Z
# 1            1  2023-12-25T16:00:08Z
# 2            2  2023-12-18T16:00:18Z
# 3            3  2023-12-11T16:00:31Z
# 4            4  2023-12-04T16:00:40Z
# 5            5  2023-11-27T16:00:13Z
# 6            6  2023-11-20T16:00:29Z
# 7            7  2023-11-13T16:00:28Z
# 8            8  2023-11-06T16:00:12Z
# 9            9  2023-10-30T16:00:36Z
# 10          10  2023-10-23T15:00:24Z
# 11          11  2023-10-16T15:00:09Z
# 12          12  2023-10-09T15:00:33Z
# 13          13  2023-10-02T15:00:29Z
# 14          14  2023-09-25T15:00:06Z
# 15          15  2023-09-18T15:00:18Z
# 16          16  2023-09-11T15:00:22Z
# 17          17  2023-09-04T15:00:13Z
# 18          18  2023-08-28T15:00:02Z
# 19          19  2023-08-21T15:00:25Z
# 20          20  2023-08-14T15:00:38Z
# 21          21  2023-08-07T15:00:14Z
# 22          22  2023-07-31T15:00:07Z
# 23          23  2023-07-24T15:00:46Z
# 24          24  2023-07-24T14:59:00Z
#
#                                                 title  \
# 0   After ten years, it's time to stop weekly videos.
# 1          People are going to be angry about pylons.
# 2        Why the government drops flies on California
# 3      A robot just swapped my electric car's battery
# 4                  Why don't subtitles match dubbing?
# 5         Why use many streetlights when one will do?
# 6             These tiny ships have a serious purpose
# 7                 Every mistake I've made since 2014.
# 8   Does the language you speak change how you think?
# 9      Boarding planes could have been very different
# 10      0-100 in less than a second. And I'm driving.
# 11                                      there’dn’t’ve
# 12  I finally rode the weird, curved German elevator.
# 13     The largest telescope that will ever be built*
# 14             Spherical houses weren't a great idea.
# 15          How languages steal words from each other
# 16        This library has every book ever published.
# 17                           Why are adverts so loud?
# 18       This man built his office inside an elevator
# 19     No-one built these for 5,000 years… until now.
# 20     This town throws pennies at people. They hurt.
# 21  This town banned cars (except tiny electric ones)
# 22                      Storing dead people at -196°C
# 23            A bear found my GoPro and took a selfie
# 24    Grizzly bear GoPro selfie: raw unedited footage
#
#                                           description      videoId
# 0   Find me here: ❓ LATERAL, free weekly podcast: ...  7DKv5H5Frt0
# 1   Britain's power grid is turning inside-out, wh...  F0JDK_71yDg
# 2   There's a good reason for it. ■ More about the...  Zl_5LT2fzak
# 3   Nio is a Chinese auto maker that offers an alt...  hNZy603as5w
# 4   Translation is really difficult. ■ AD: 👨‍💻 Nor...  pU9sHwNKc2c
# 5   The moonlight towers of Austin, Texas, are the...  LDiXNsWQzD0
# 6   At Port Iława in Poland, pilots and captains o...  jplrbxI5GN8
# 7   Time to correct the record. ■ AD: 👨‍💻 NordVPN'...  lIbfMjZ0ME4
# 8   No. Mostly. • \nWritten with Molly Ruhl and Gr...  CmZdGo6b5yA
# 9   There's a world in which everyone boards plane...  j3OqAN4ISOw
# 10  AMZ Racing's "mythen" holds the world record f...  XQIu5tZ0vbQ
# 11  This script was a nightmare to pronounce. • \n...  CkZyZFa5qO0
# 12  At the New Town Hall, the Neues Rathaus, in Ha...  ZgDBIzClmPg
# 13  The asterisk is important. ■ AD: 👨‍💻 NordVPN's...  QqRREz0iBes
# 14  The Bolwoningen, in Den Bosch, in the Netherla...  3kwDVw0u4Kw
# 15  This is the only pirate reference you're getti...  TFpzps-DCb0
# 16  The British Library is one of the six legal de...  ZNVuIU6UUiM
# 17  This was so much more complex than I thought. ...  Is_wu0VRIqQ
# 18  The Baťa Skyscraper, in Zlín, Czechia, is a la...  1yfX84RMQ3M
# 19  Long barrows are Neolithic constructions that ...  _G2Q1qsoGEU
# 20  The Honiton Hot Pennies ceremony is the result...  nbafT2w0cCQ
# 21  Zermatt, in Switzerland, bans all private cars...  R2oD1ZHNMFE
# 22  In Switzerland, there's a new cryonics company...  85BykUan6pw
# 23  An unexpected update! Thanks to @KarenPuzzles ...  xq4ZkfojSis
# 24  This footage is public domain, and the raw fil...  Oarf76MCrss

# %%
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()
client = OpenAI()

# %%
def get_location(row):
    completion = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": "given a video description and title, give the location that the video was filmed.\
              If it's not extremely clear, say \"no location found\" all lowercase with no punctuation. \
             get as specific of a location as possible with the given inputs. \
                Especially if there is a bulilding named in the description, this should be the response.\
             Ideally, output should be formatted 'location, city, state, country' if applicable. If not applicable, just skip"},
            {
                "role": "user",
                "content": f'title: "{row["title"]}", description:"{row["description"]}"'
            }
        ]
    )

    return completion.choices[0].message.content

responses = df.apply(get_location, axis=1)

# %%
df["location"] = responses

# %%
df.to_csv("./data_with_loc.csv")
