# %%
import pandas as pd

# %%
df = pd.read_csv("./data.csv")
df
# Out:
#              publishedAt                                              title  \
# 0   2025-03-26T14:30:28Z  Ep 3 - We Raced To Visit The Most European Cou...
# 1   2025-03-19T14:30:31Z  Ep 2 - We Raced To Visit The Most European Cou...
# 2   2025-03-12T14:30:10Z  We Raced To Visit The Most European Countries ...
# 3   2025-03-05T15:30:01Z               Jet Lag: Schengen Showdown [Trailer]
# 4   2025-01-22T15:30:09Z      We Played Hide And Seek Across Japan - Finale
# ..                   ...                                                ...
# 75  2022-07-13T16:14:12Z  Day 2 - We Raced To Circumnavigate The Globe I...
# 76  2022-07-06T16:32:58Z  We Raced To Circumnavigate The Globe In 100 Hours
# 77  2022-06-08T16:18:38Z  Our Flight Got Diverted at the Worst Possible ...
# 78  2022-06-01T14:59:33Z  Flying 1,200 Miles to Ruin Our Boss' Plan - Co...
# 79  2022-05-25T17:56:43Z  We Played Connect 4 by Travelling to Actual US...
#
#                                           description      videoId
# 0   Watch episode four of Schengen Showdown right ...  dsDy5VAw-xo
# 1   Watch episode three of Schengen Showdown right...  lSwkoIQLFLo
# 2   Watch episode two of Schengen Showdown right n...  EJFAw1VRcsA
# 3   Watch now at http://nebula.tv/jetlag\n\nPremie...  3Qyaocw0u3o
# 4   Buy the Hide and Seek Home Game: https://store...  5UAM-ZKBcZs
# ..                                                ...          ...
# 75  Get $20 off an annual Nebula subscription by s...  tq7KarjTwTA
# 76  Get $20 off an annual Nebula subscription by s...  Gta43oOV4Ag
# 77  Get $20 off an annual Nebula subscription by s...  DSuva0TtdYs
# 78  Get $20 off an annual Nebula subscription by s...  LmjcQ9UoBjc
# 79  Get $20 off an annual Nebula subscription by s...  oZSUxdzgA08
#
# [80 rows x 4 columns]

# %%
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()
client = OpenAI()

# %%
def get_location(row):
    completion = client.chat.completions.create(
        model="gpt-4o",
messages=[
    {
        "role": "system",
        "content": (
            "You are a location assignment assistant for a travel competition race game show. "
            "Your task is to determine the **specific filming location** based on the title and description provided.\n\n"
            "**STRICT RULES (NO EXCEPTIONS):**\n"
            "✅ **ALWAYS** provide a specific location—city, landmark, or district. NEVER respond with 'various locations' or 'unclear'.\n"
            "✅ **NO EXPLANATIONS OR JUSTIFICATIONS.** The response **must be the location ONLY**, formatted as:\n"
            "   **'Landmark (if applicable), City, (State), Country'**\n"
            "✅ **NO DUPLICATES.** If the same city appears across episodes, differentiate by naming a district, landmark, or nearby area.\n"
            "✅ **NAMED LANDMARKS TAKE PRIORITY.** If a location (e.g., Eiffel Tower) is mentioned in the description, it **MUST** be used.\n"
            "✅ **DO NOT say 'it's unclear' or 'inferred'.** Even if uncertain, make an educated guess and output **ONLY** the final location.\n"
            "\n"
            "**IF YOU CANNOT DETERMINE A LOCATION, YOU MUST STILL GUESS AND OUTPUT A SPECIFIC PLACE.**"
        )
    },
    {
        "role": "user",
        "content": f'title: "{row["title"]}", description: "{row["description"]}"'
    }
]




    )

    return completion.choices[0].message.content

responses = df.apply(get_location, axis=1)

# %%
df["location"] = responses

# %%
df.to_csv("./data_with_loc.csv")
